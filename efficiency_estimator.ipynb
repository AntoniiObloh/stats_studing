# %%
import numpy as np
import pandas as pd 
import os

import scipy.stats as sts 
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')
# %matplotlib inline

# %%
uniform_rv = sts.uniform(0,5)

n_obs = 100 
x = uniform_rv.rvs(size = (n_obs,1000))
x.shape
# Out:
# (100, 1000)

# %%
theta_1 = 2*np.mean(x,axis=0)
theta_2 = (n_obs + 2)/n_obs*np.max(x,axis=0)

# %%
plt.figure(figsize=(14,8))
plt.hist(theta_1, bins=100, alpha=0.5, label="Moment method")
plt.hist(theta_2, bins=50, alpha=0.5, label="ML method")
# Out:
# (array([  1.,   0.,   0.,   1.,   0.,   1.,   1.,   1.,   0.,   1.,   0.,
#           0.,   0.,   2.,   0.,   1.,   0.,   0.,   1.,   4.,   3.,   2.,
#           5.,   4.,   5.,   3.,   3.,  10.,   5.,   8.,  10.,  16.,  14.,
#          12.,  17.,  24.,  22.,  24.,  21.,  30.,  43.,  49.,  48.,  65.,
#          73.,  72.,  66.,  99., 110., 123.]),
#  array([4.74489496, 4.75199698, 4.759099  , 4.76620102, 4.77330304,
#         4.78040506, 4.78750707, 4.79460909, 4.80171111, 4.80881313,
#         4.81591515, 4.82301717, 4.83011919, 4.8372212 , 4.84432322,
#         4.85142524, 4.85852726, 4.86562928, 4.8727313 , 4.87983331,
#         4.88693533, 4.89403735, 4.90113937, 4.90824139, 4.91534341,
#         4.92244543, 4.92954744, 4.93664946, 4.94375148, 4.9508535 ,
#         4.95795552, 4.96505754, 4.97215955, 4.97926157, 4.98636359,
#         4.99346561, 5.00056763, 5.00766965, 5.01477167, 5.02187368,
#         5.0289757 , 5.03607772, 5.04317974, 5.05028176, 5.05738378,
#         5.06448579, 5.07158781, 5.07868983, 5.08579185, 5.09289387,
#         5.09999589]),
#  <BarContainer object of 50 artists>)

# %%
np.var(theta_1)
# Out:
# 0.08425847750518588

# %%
np.var(theta_2)
# Out:
# 0.002623676348932289
